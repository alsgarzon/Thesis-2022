# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Al SWC
x_1 = np.array([1, 4, 8, 10]) # array for x
y_1 = np.array([0.00000002104, 0.2658, 3.057, 4.373]) # array for y

x_2 = np.array([1, 4, 8, 10]) # array for x
y_2 = np.array([0.00000001746, 0.0006294, 2.428, 3.749]) # array for y

x_3 = np.array([1, 4, 8, 10]) # array for x
y_3 = np.array([0.00000001746, 0.07888, 2.52, 3.851]) # array for y

x_4 = np.array([1, 4, 8, 10]) # array for x
y_4 = np.array([0.00000002445, 0.000009896, 1.134, 2.672]) # array for y

x_5 = np.array([1, 4, 8, 10]) # array for x
y_5 = np.array([0.00000006967, 0.00002102, 0.4603, 1.404]) # array for y

x_6 = np.array([1, 4, 8, 10]) # array for x
y_6 = np.array([0.1825, 2.531, 5.527, 6.55]) # array for y

#WC
x_7 = np.array([1, 4, 8, 10]) # array for x
y_7 = np.array([0.0000005226, 0.004028, 0.9028, 1.698]) # array for y

x_8 = np.array([1, 4, 8, 10]) # array for x
y_8 = np.array([0.0000005243, 0.004984, 0.9328, 1.732]) # array for y

x_9 = np.array([1, 4, 8, 10]) # array for x
y_9 = np.array([0.0000004996, 0.00004973, 0.2938, 0.8986]) # array for y

x_10 = np.array([1, 4, 8, 10]) # array for x
y_10 = np.array([0.0000005412, 0.00005428, 0.3467, 0.9796]) # array for y

# %%
#Al-LiBH4-Al
plt.plot(x_5, y_5,marker = '*',label = "Al") #blue Al
plt.plot(x_6, y_6,marker = 'D',label = "No Shield") 
plt.plot(x_1, y_1,marker = 'o',label = "SWC-A")  #1-9-1%
plt.plot(x_2, y_2,marker = '+',label = "SWC-B") #3-6-1%
plt.plot(x_3, y_3,marker = 'x',label = "SWC-C") #1-3-6%
plt.plot(x_4, y_4,marker = 's',label = "SWC-D") #4-2-4%

#WC-LiBH4-SBR
plt.plot(x_7, y_7,marker = 'o',label = "Ratio A")  #5-5-90%
plt.plot(x_8, y_8,marker = '+',label = "Ratio B") #5-15-80%
plt.plot(x_9, y_9,marker = 'x',label = "Ratio C") #10-20-70%
plt.plot(x_10, y_10,marker = 's',label = "Ratio D") #10-40-50%

plt.xlabel('Electron Energy (MeV)')
plt.ylabel('Particle Flux (cm\N{SUPERSCRIPT TWO}/source)')

plt.legend()
plt.show()
